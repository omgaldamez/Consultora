# %%
import xlrd
# comentarios
#path: direccion de archivo

import os
import pandas as pd
import numpy as np
import array as arr
import altair as alt

pd.set_option("display.max_columns",None)

# %%
cardsContent = pd.read_csv("Cards_Content.csv")
cardsContent
# Out:
#    ID_Project                    Title  \
# 0           1          Nuevo Horizonte
# 1           2         Health Economics
# 2           3             EcoEmissions
# 3           4  Health Trends Dashboard
# 4           5     Portafolio de diseño
# 5           6               Custom Viz
#
#                                              Content  \
# 0  La ruta de los psicodélicos y su promesa terap...
# 1  Indicadores de Salud del Sector Público de México
# 2                Dashboard interactivo en Power BI\n
# 3                Dashboard interactivo en Power BI\n
# 4                                   Trabajo creativo
# 5                            Gráficos Personalizados
#
#                                                About  \
# 0  Investigación sobre el auge de la investigació...
# 1  Página web interactiva del gasto público en sa...
# 2     Comparativo de emisiones de efecto invernadero
# 3  Explore visualmente la evolución de indicadore...
# ...

# %%
cardsContent.to_json(r"../routes/portfolio/cardsContent.json",orient="table")
